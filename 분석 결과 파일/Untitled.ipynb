# %%
import numpy as np

import pandas as pd



import matplotlib.pyplot as plt

import seaborn as sns

plt.rcParams['figure.figsize'] = [10, 8]

# %%
df=pd.read_csv('bugs_hppoint_year_title.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  year                                  title  hppoint
# 0           0  2018                 사랑을 했다 (LOVE SCENARIO)        7
# 1           1  2018                                   그날처럼        5
# 2           2  2018                                     선물        5
# 3           3  2018  모든 날, 모든 순간 (Every day, Every Moment)        5
# 4           4  2018                   뚜두뚜두 (DDU-DU DDU-DU)        6

# %%
del df['title']

# %%
df
# Out:
#       year  hppoint
# 0     2018        7
# 1     2018        5
# 2     2018        5
# 3     2018        5
# 4     2018        6
# 5     2018        6
# 6     2018        6
# 7     2018        4
# 8     2018        7
# 9     2018        6
# 10    2018        5
# 11    2018        5
# 12    2018        5
# 13    2018        6
# 14    2018        7
# 15    2018        8
# 16    2018        6
# 17    2018        4
# 18    2018        7
# 19    2018        7
# 20    2018        8
# 21    2018        8
# 22    2018        5
# 23    2018        4
# 24    2018        5
# 25    2018        7
# 26    2018        3
# 27    2018        6
# 28    2018        6
# 29    2018        6
# ...    ...      ...
# 4263  1965        3
# 4264  1965        2
# 4265  1964        2
# 4266  1964        4
# 4267  1964        2
# 4268  1964        2
# 4269  1964        3
# 4270  1964        4
# 4271  1964        3
# 4272  1964        4
# 4273  1964        2
# 4274  1964        2
# 4275  1964        3
# ...

# %%
pivot = df.pivot_table(index='year', columns='Make', aggfunc=np.mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-dfc7959470b5> in <module>
# ----> 1 df1 = df.pivot('year', 'hppoint')
#       2 df1
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    5192         """
#    5193         from pandas.core.reshape.reshape import pivot
# -> 5194         return pivot(self, index=index, columns=columns, values=values)
#    5195
#    5196     _shared_docs['pivot_table'] = """
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/reshape.py in pivot(self, index, columns, values)
#     413             indexed = self._constructor_sliced(self[values].values,
#     414                                                index=index)
# --> 415     return indexed.unstack(columns)
#     416
#     417
#
# ...
