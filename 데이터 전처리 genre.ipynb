# %%
from selenium import webdriver as wd
import time
import pandas as pd

# %%
bugs = pd.read_csv("Bugs.csv")

# %%
bugs["oneGenre"] = " "

# %%
bugs["singeredit"] = bugs["singer"].str.split('(').str[0]

# %%
bugs.head()
# Out:
#                year                                  title  \
# 0  2018년 베스트 가요 콜렉션                 사랑을 했다 (LOVE SCENARIO)
# 1  2018년 베스트 가요 콜렉션                                   그날처럼
# 2  2018년 베스트 가요 콜렉션                                     선물
# 3  2018년 베스트 가요 콜렉션  모든 날, 모든 순간 (Every day, Every Moment)
# 4  2018년 베스트 가요 콜렉션                   뚜두뚜두 (DDU-DU DDU-DU)
#
#                       singer          genre runtime     type  \
# 0                       iKON           랩/힙합   03:29  그룹 (남성)
# 1                        장덕철       발라드/댄스/팝   03:52  그룹 (남성)
# 2            멜로망스(MeloMance)   인디, 발라드/댄스/팝   04:20  듀오 (남성)
# 3  폴킴(Paul Kim) CONNECT 아티스트  발라드/댄스/팝, OST   03:30  솔로 (남성)
# 4                  BLACKPINK       발라드/댄스/팝   03:29  그룹 (여성)
#
#                                                lyric oneGenre singeredit
# 0  사랑을 했다 우리가 만나\r\n지우지 못할 추억이 됐다\r\n볼만한 멜로드라마\r\...                iKON
# 1  참 많은 시간이 흘러가고\r\n넌 어떻게 사는지 참 궁금해\r\n날 걱정하는 사람들...                 장덕철
# 2  빛이 들어오면 자연스레 뜨던 눈 \r\n그렇게 너의 눈빛을 보곤\r\n사랑에 눈을 ...                멜로망스
# 3  네가 없이 웃을 수 있을까\r\n생각만 해도 눈물이나\r\n힘든 시간 날 지켜준 사...                  폴킴
# 4  착한 얼굴에 그렇지 못한 태도\r\n가녀린 몸매 속 가려진 Volume은 두 배로\...           BLACKPINK

# %%
path = "/Users/YONGHA.LEE/chromedriver"
driver = wd.Chrome(path)

# %%
url = 'https://www.melon.com/'
driver.get(url)

# %%
for index, row in bugs.iterrows():
    try: 
        elem = driver.find_element_by_id('top_search')
        finder = driver.find_element_by_css_selector('.btn_icon.search_m')

        word = bugs.loc[index, "title"] + " " + bugs.loc[index, "singeredit"]
        elem.clear()
        elem.send_keys(word)
        finder.click()    

        finder2 = driver.find_element_by_css_selector('.btn_icon_detail')
        finder2.click()

        bugs["oneGenre"][index] = driver.find_element_by_css_selector('#downloadfrm > div > div > div.entry > div.meta > dl > dd:nth-child(6)').text
    except:
        bugs["oneGenre"][index] = bugs["genre"][index]

# %%
del bugs["singeredit"]

# %%
driver.close()

# %%
bugs["genre"] = bugs["oneGenre"]

# %%
del bugs["oneGenre"]

# %%
bugs.head(30)
# Out:
#                 year                                  title  \
# 0   2018년 베스트 가요 콜렉션                 사랑을 했다 (LOVE SCENARIO)
# 1   2018년 베스트 가요 콜렉션                                   그날처럼
# 2   2018년 베스트 가요 콜렉션                                     선물
# 3   2018년 베스트 가요 콜렉션  모든 날, 모든 순간 (Every day, Every Moment)
# 4   2018년 베스트 가요 콜렉션                   뚜두뚜두 (DDU-DU DDU-DU)
# 5   2018년 베스트 가요 콜렉션                                     뿜뿜
# 6   2018년 베스트 가요 콜렉션                                    You
# 7   2018년 베스트 가요 콜렉션                              그때 헤어지면 돼
# 8   2018년 베스트 가요 콜렉션                         Roller Coaster
# 2   빛이 들어오면 자연스레 뜨던 눈 \r\n그렇게 너의 눈빛을 보곤\r\n사랑에 눈을 ...           발라드
# 3   네가 없이 웃을 수 있을까\r\n생각만 해도 눈물이나\r\n힘든 시간 날 지켜준 사...           발라드
# 4   착한 얼굴에 그렇지 못한 태도\r\n가녀린 몸매 속 가려진 Volume은 두 배로\...          랩/힙합
# 5   설레어 너와 나의 랑데뷰 (랑데뷰)\r\n내 마음을 들었다 놨다 해 맘대루 (맘대루...            댄스
# 6   어떻게 난 해야 해 니가 떠난다고 말하면\r\n난 혼자 남겨지는 게 더 두려울 텐데...           발라드
# 7   나를 사랑하는 법은 어렵지 않아요\r\n지금 모습 그대로 나를 꼭 안아주세요\r\n...           발라드
# 8   I remember very first time in love\r\nI rememb...            댄스
# 9   내일이 올 걸 아는데\r\n난 핸드폰을 놓지 못해\r\n잠은 올 생각이 없대 yea...      R&B/Soul
# 10  이별을 말하고 넌 괜찮은 거니\r\n여전히 내 하루는 온통 네 생각에\r\n뜬 눈으...           발라드
# 11  멈춘 시간 속\r\n잠든 너를 찾아가\r\n아무리 막아도\r\n결국 너의 곁인 걸\...  인디음악, 일렉트로니카
# 12  저 오늘 떠나요 공항으로\r\n핸드폰 꺼 놔요\r\n제발 날 찾진 말아줘\r\n시끄...    인디음악, 록/메탈
# 13  습관처럼 떠오르던\r\n눈에 아른거리던 네 모습이\r\n더는 그려지지 않아\r\n거...      R&B/Soul
# 14  Who dat who dat who dat boy\r\n수많은 사람 속 눈에 띈\r...            댄스
# 15  위험해 아슬아슬해\r\n간신히 끈을 잡았는데\r\n넌 가위질을 하려고 해\r\n너의...           발라드
# 16  손끝이 시리더니 벌써 봄이 왔네\r\n꿈같은 바람이 불어 곳곳에\r\n여느 때 와는...            댄스
# 17  이 밤 그날의 반딧불을 \r\n당신의 창 가까이 보낼게요\r\n음 사랑한다는 말 이...           발라드
# 18  Yeah yeah yeah yeah yeah\r\nCome and be my lov...            댄스
# 19  그땐 참 좋았는데 말이야\r\n너와 함께할 수만 있다면\r\n때론 외롭고 슬퍼도 말...      R&B/Soul
# 20  매일같이 영화 속에서나\r\n책 속에서나 드라마 속에서\r\n사랑을 느껴\r\nUm...            댄스
# 21  나나나나나나나\r\n나나나나나나나\r\nYou and me in the moonli...            댄스
# 22  떨려오는 별빛 반짝이는데\r\n넌 어디를 보고 있는지\r\n금방이라도 사라질 것 같...            댄스
# 23  비가 내리다 말다\r\n우산을 챙길까 말까\r\ntv엔 맑음이라던데\r\n네 마음도...      R&B/Soul
# 24  니가 없는 자리는 투명한 꿈처럼\r\n허전한 듯 나를 감싸고\r\n무뎌진 마음을\r...      R&B/Soul
# 25  떠나지 마 Just stay\r\n지금 이 시간을 멈춘 채\r\n너와 함께라면 난\...            댄스
# 26  멀리 배웅하던 길\r\n여전히 나는 그곳에 서서\r\n그대가 사랑한\r\n이 계절의...           발라드
# 27  멋대로 날 찾아와서 모든 걸 다 적시고\r\n내 마음도 짙어져 널 원할 때쯤에\r\...           발라드
# 28  첫눈에 널 알아보게 됐어\r\n서롤 불러왔던 것처럼\r\n내 혈관 속 DNA가 말해...          랩/힙합
# 29  오늘도 난 술을 마셔 우울하니까\r\n네가 또 생각나니까\r\n침대 위에 놓인 전활...      R&B/Soul
